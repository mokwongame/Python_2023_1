# %%
import matplotlib.pyplot as plt # as: 가명, 별명 붙이기
import numpy as np # Python에 배열(array) 자료 구조 추가
#import math # 수학 함수: math.으로 멤버 접근
from math import * # 모든 수학 함수, 변수를 math. 없이

# %%
def unitStep(x):
    if x > 0: return 1
    elif x == 0: return 0.5
    else: return 0

# %%
# x축용 list 생성: numpy 배열을 이용해서
x = list(np.arange(-2, 2, 0.01)) # arange(시작, 끝, 간격)
#print(x)

# %%
y = [] # list 초기화
for xval in x: # list x에서 값을 빼내서 xval에 할당
    y.append(unitStep(xval))
#print(y)

# %%
plt.plot(x, y) # 그래프 그리기
plt.grid(True) # 눈금선 표시
