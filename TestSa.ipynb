# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *

# %%
def Sa(x):
    if x == 0: return 1
    else: return sin(x)/x

# %%
Sa(0)
# Out:
# 1

# %%
x = 0
#y = sin(x)/x
#print(y)

# %%
x = np.arange(-10., 10., 0.001)
y = []
for xv in x:
    y.append(Sa(xv))

# %%
plt.plot(x, y)
plt.grid(True)
